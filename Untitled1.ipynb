# %% [markdown]
# <a href="https://colab.research.google.com/github/seoyeong123/midterm24/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2023013220

# %% [markdown]
# Midterm 2024: Seoyeong Lim

# %%
##GTTS Question
# !pip install gTTS
from gtts import gTTS
from lPython,display improt Audio, display
text="Hello student."
language="en"
speech=gTTS(text=text, lang=language, slow=false)
speech. save("output.mp3")
display(Audio("output.mp3", autoplay=true))

# %%
##Countdown Question

# %%
##Index Question
#Dropdownbox
Cardinal_number="2"
Cardinal_number= int(Cardinal_number)
Words=['First', 'Second', 'Third', 'Fourth']
print("The ordinal expression:", words[cardinal_number])

# %%
##Function Qusetion
def divide_number(num1, num2):
 result=num1/num2
 return  result
 divide_number(20,4)

# %%
##Dictionary Question
grades = { "Bob":'80', "John":'52', "San":'84' }
socre=grades["Bob"]
print("Bob")

# %%
#Name question
x='My name is'
y="Seoyeong Lim"
print(x, y)

# %%
#'Mary, 1998, Ohio: and Joh, 1999, Boston.'
X=input('name'); y=input('born in'); z=input('hometown')
print(X)
print(y)
print(z)
